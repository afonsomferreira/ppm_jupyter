# %% [markdown]
# ## This Jupyter notebook will show you to perform basic calculations and plots with 2 dimensional data (matrices, )
#
# ## We will compare two images:
# ### * MODIS-AQUA - 31st August 2005
# ### * MODIS-AQUA - 16th Feburary 2017
#
# Now, we will need to import several packages/toolboxes that are essential for nearly every scientific work in Python.

# %%
import os #change folders
import numpy as np # perform calculations and basic math
import matplotlib.pyplot as plt # plot data
import pandas as pd # work with dataframes,tables, spreadsheets, etc.
import netCDF4 as nc4 # work with netcdf files, the standard file for satellite 2D and 3D data

# %% [markdown]
# ## Now, lets load each image using the netCDF4 module.

# %%
# Let's open the first image (31st August 2005)
file = 'A2005243140500.L2_LAC_OC.x 2.hdf' #write the name of the file
fh = nc4.Dataset(file, mode='r') #open the file in python
print(fh) #print full details of the image
#print(fh.variables)
# Out:
# {'year': <class 'netCDF4._netCDF4.Variable'>
# >i4 year(Number of Scan Lines)
#     long_name: Scan year
#     valid_range: [1996 2038]
#     units: years
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'day': <class 'netCDF4._netCDF4.Variable'>
# >i4 day(Number of Scan Lines)
#     long_name: Scan day of year
#     valid_range: [  1 366]
#     units: days
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'msec': <class 'netCDF4._netCDF4.Variable'>
# >i4 msec(Number of Scan Lines)
#     long_name: Scan-line time, milliseconds of day
#     valid_range: [       0 86399999]
#     units: milliseconds
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'tilt': <class 'netCDF4._netCDF4.Variable'>
# >f4 tilt(Number of Scan Lines)
#     long_name: Tilt angle for scan line
#     valid_range: [-20.1  20.1]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'slon': <class 'netCDF4._netCDF4.Variable'>
# >f4 slon(Number of Scan Lines)
#     long_name: Scan start-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'clon': <class 'netCDF4._netCDF4.Variable'>
# >f4 clon(Number of Scan Lines)
#     long_name: Scan center-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'elon': <class 'netCDF4._netCDF4.Variable'>
# >f4 elon(Number of Scan Lines)
#     long_name: Scan end-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'slat': <class 'netCDF4._netCDF4.Variable'>
# >f4 slat(Number of Scan Lines)
#     long_name: Scan start-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'clat': <class 'netCDF4._netCDF4.Variable'>
# >f4 clat(Number of Scan Lines)
#     long_name: Scan center-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'elat': <class 'netCDF4._netCDF4.Variable'>
# >f4 elat(Number of Scan Lines)
#     long_name: Scan end-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'csol_z': <class 'netCDF4._netCDF4.Variable'>
# >f4 csol_z(Number of Scan Lines)
#     long_name: Scan center-pixel solar zenith angle
#     valid_range: [  0. 180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'longitude': <class 'netCDF4._netCDF4.Variable'>
# >f4 longitude(Number of Scan Lines, Number of Pixel Control Points)
#     long_name: Longitudes at control points
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'latitude': <class 'netCDF4._netCDF4.Variable'>
# >f4 latitude(Number of Scan Lines, Number of Pixel Control Points)
#     long_name: Latitudes at control points
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'aot_869': <class 'netCDF4._netCDF4.Variable'>
# >i2 aot_869(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Aerosol optical thickness at 869 nm
#     slope: 1e-04
#     intercept: 0.0
#     units: dimensionless
#     standard_name: atmosphere_absorption_optical_thickness_due_to_ambient_aerosol
#     bad_value_scaled: -32767
#     bad_value_unscaled: -3.2767
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'angstrom': <class 'netCDF4._netCDF4.Variable'>
# >i2 angstrom(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Aerosol Angstrom exponent, 443 to 865 nm
#     slope: 1e-04
#     intercept: 2.5
#     units: dimensionless
#     standard_name: aerosol_angstrom_exponent
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.7767
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_412': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_412(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 412 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 171.18178
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_443': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_443(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 443 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 188.75414
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_469': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_469(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 469 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 203.52333
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_488': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_488(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 488 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 194.1784
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_531': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_531(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 531 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 185.94444
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_547': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_547(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 547 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 186.99834
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_555': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_555(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 555 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 183.75674
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_645': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_645(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 645 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 158.74379
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_667': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_667(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 667 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 152.43858
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_678': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_678(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 678 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 148.1367
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'chlor_a': <class 'netCDF4._netCDF4.Variable'>
# >f4 chlor_a(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Chlorophyll Concentration, OC3 Algorithm
#     slope: 1.0
#     intercept: 0.0
#     units: mg m^-3
#     standard_name: chlorophyll_concentration_in_sea_water
#     bad_value_scaled: -32767.0
#     bad_value_unscaled: -32767.0
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Kd_490': <class 'netCDF4._netCDF4.Variable'>
# >i2 Kd_490(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Diffuse attenuation coefficient at 490 nm, KD2 algorithm
#     slope: 0.0002
#     intercept: 0.0
#     units: m^-1
#     standard_name: diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -6.5534
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'pic': <class 'netCDF4._netCDF4.Variable'>
# >i2 pic(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Calcite Concentration, Balch and Gordon
#     slope: 2e-06
#     intercept: 0.065
#     units: mol m^-3
#     standard_name: mole_concentration_of_particulate_inorganic_carbon_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.00053400546
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'poc': <class 'netCDF4._netCDF4.Variable'>
# >i2 poc(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Particulate Organic Carbon, D. Stramski, 2007 (443/555 version)
#     slope: 0.2
#     intercept: 6400.0
#     units: mg m^-3
#     standard_name: mole_concentration_of_particulate_organic_carbon_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -153.3999
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'cdom_index': <class 'netCDF4._netCDF4.Variable'>
# >i2 cdom_index(Number of Scan Lines, Pixels per Scan Line)
#     long_name: CDOM index, Morel 2009 algorithm
#     slope: 0.0002
#     intercept: 6.4
#     units: dimensionless
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.15339994
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'ipar': <class 'netCDF4._netCDF4.Variable'>
# >i2 ipar(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Instantaneous Photosynthetically Available Radiation
#     slope: 1e-07
#     intercept: 0.0
#     units: Ein m^-2 s^-1
#     standard_name: downwelling_photosynthetic_photon_radiance_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.0032767002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'nflh': <class 'netCDF4._netCDF4.Variable'>
# >i2 nflh(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Normalized Fluorescence Line Height
#     slope: 1e-05
#     intercept: 0.0
#     units: mW cm^-2 um^-1 sr^-1
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.32766998
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'par': <class 'netCDF4._netCDF4.Variable'>
# >i2 par(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Photosynthetically Available Radiation, R. Frouin
#     slope: 0.002
#     intercept: 65.5
#     units: Ein m^-2 day^-1
#     standard_name: surface_downwelling_photosynthetic_photon_flux_in_air
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.03400421
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'l2_flags': <class 'netCDF4._netCDF4.Variable'>
# >i4 l2_flags(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Level-2 Processing Flags
#     slope: 1.0
#     intercept: 0.0
#     units: dimensionless
#     f01_name: ATMFAIL
#     f02_name: LAND
#     f03_name: PRODWARN
#     f04_name: HIGLINT
#     f05_name: HILT
#     f06_name: HISATZEN
#     f07_name: COASTZ
#     f08_name: SPARE
#     f09_name: STRAYLIGHT
#     f10_name: CLDICE
#     f11_name: COCCOLITH
#     f12_name: TURBIDW
#     f13_name: HISOLZEN
#     f14_name: SPARE
#     f15_name: LOWLW
#     f16_name: CHLFAIL
#     f17_name: NAVWARN
#     f18_name: ABSAER
#     f19_name: SPARE
#     f20_name: MAXAERITER
#     f21_name: MODGLINT
#     f22_name: CHLWARN
#     f23_name: ATMWARN
#     f24_name: SPARE
#     f25_name: SEAICE
#     f26_name: NAVFAIL
#     f27_name: FILTER
#     f28_name: SSTWARN
#     f29_name: SSTFAIL
#     f30_name: HIPOL
#     f31_name: PRODFAIL
#     f32_name: SPARE
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -2147483647 used, 'wavelength': <class 'netCDF4._netCDF4.Variable'>
# >i4 wavelength(total band number)
#     long_name: Wavelengths
#     units: nm
# unlimited dimensions:
# current shape = (24,)
# filling on, default _FillValue of -2147483647 used, 'cntl_pt_cols': <class 'netCDF4._netCDF4.Variable'>
# >i4 cntl_pt_cols(Number of Pixel Control Points)
#     long_name: Pixel control points
#     units: none
# unlimited dimensions:
# current shape = (403,)
# filling on, default _FillValue of -2147483647 used, 'cntl_pt_rows': <class 'netCDF4._netCDF4.Variable'>
# >i4 cntl_pt_rows(Number of Scan Lines)
#     long_name: Scan control points
#     units: none
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'vcal_gain': <class 'netCDF4._netCDF4.Variable'>
# >f4 vcal_gain(band number)
#     long_name: Vicarious Calibration Gain
#     units: dimensionless
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vcal_offset': <class 'netCDF4._netCDF4.Variable'>
# >f4 vcal_offset(band number)
#     long_name: Vicarious Calibration Offset
#     units: mW cm^-2 um^-1 sr^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'F0': <class 'netCDF4._netCDF4.Variable'>
# >f4 F0(band number)
#     long_name: Mean Solar Flux
#     units: mW cm^-2 um^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'k_oz': <class 'netCDF4._netCDF4.Variable'>
# >f4 k_oz(band number)
#     long_name: Ozone Absorption Coefficient
#     units: cm^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Tau_r': <class 'netCDF4._netCDF4.Variable'>
# >f4 Tau_r(band number)
#     long_name: Rayleigh Optical Thickness
#     units: dimensionless
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used}
# <ipython-input-7-5dc25744e079>:4: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(fh.variables)

# %%
# You can also use fh.variables to read information only on the variables
print(fh.variables)
# Out:
# {'year': <class 'netCDF4._netCDF4.Variable'>
# >i4 year(Number of Scan Lines)
#     long_name: Scan year
#     valid_range: [1996 2038]
#     units: years
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'day': <class 'netCDF4._netCDF4.Variable'>
# >i4 day(Number of Scan Lines)
#     long_name: Scan day of year
#     valid_range: [  1 366]
#     units: days
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'msec': <class 'netCDF4._netCDF4.Variable'>
# >i4 msec(Number of Scan Lines)
#     long_name: Scan-line time, milliseconds of day
#     valid_range: [       0 86399999]
#     units: milliseconds
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'tilt': <class 'netCDF4._netCDF4.Variable'>
# >f4 tilt(Number of Scan Lines)
#     long_name: Tilt angle for scan line
#     valid_range: [-20.1  20.1]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'slon': <class 'netCDF4._netCDF4.Variable'>
# >f4 slon(Number of Scan Lines)
#     long_name: Scan start-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'clon': <class 'netCDF4._netCDF4.Variable'>
# >f4 clon(Number of Scan Lines)
#     long_name: Scan center-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'elon': <class 'netCDF4._netCDF4.Variable'>
# >f4 elon(Number of Scan Lines)
#     long_name: Scan end-pixel longitude
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'slat': <class 'netCDF4._netCDF4.Variable'>
# >f4 slat(Number of Scan Lines)
#     long_name: Scan start-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'clat': <class 'netCDF4._netCDF4.Variable'>
# >f4 clat(Number of Scan Lines)
#     long_name: Scan center-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'elat': <class 'netCDF4._netCDF4.Variable'>
# >f4 elat(Number of Scan Lines)
#     long_name: Scan end-pixel latitude
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'csol_z': <class 'netCDF4._netCDF4.Variable'>
# >f4 csol_z(Number of Scan Lines)
#     long_name: Scan center-pixel solar zenith angle
#     valid_range: [  0. 180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'longitude': <class 'netCDF4._netCDF4.Variable'>
# >f4 longitude(Number of Scan Lines, Number of Pixel Control Points)
#     long_name: Longitudes at control points
#     valid_range: [-180.  180.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'latitude': <class 'netCDF4._netCDF4.Variable'>
# >f4 latitude(Number of Scan Lines, Number of Pixel Control Points)
#     long_name: Latitudes at control points
#     valid_range: [-90.  90.]
#     units: degrees
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'aot_869': <class 'netCDF4._netCDF4.Variable'>
# >i2 aot_869(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Aerosol optical thickness at 869 nm
#     slope: 1e-04
#     intercept: 0.0
#     units: dimensionless
#     standard_name: atmosphere_absorption_optical_thickness_due_to_ambient_aerosol
#     bad_value_scaled: -32767
#     bad_value_unscaled: -3.2767
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'angstrom': <class 'netCDF4._netCDF4.Variable'>
# >i2 angstrom(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Aerosol Angstrom exponent, 443 to 865 nm
#     slope: 1e-04
#     intercept: 2.5
#     units: dimensionless
#     standard_name: aerosol_angstrom_exponent
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.7767
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_412': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_412(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 412 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 171.18178
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_443': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_443(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 443 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 188.75414
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_469': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_469(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 469 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 203.52333
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_488': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_488(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 488 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 194.1784
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_531': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_531(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 531 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 185.94444
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_547': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_547(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 547 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 186.99834
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_555': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_555(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 555 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 183.75674
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_645': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_645(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 645 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 158.74379
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_667': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_667(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 667 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 152.43858
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'Rrs_678': <class 'netCDF4._netCDF4.Variable'>
# >i2 Rrs_678(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Remote sensing reflectance at 678 nm
#     slope: 2e-06
#     intercept: 0.05
#     units: sr^-1
#     solar_irradiance: 148.1367
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.015534002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'chlor_a': <class 'netCDF4._netCDF4.Variable'>
# >f4 chlor_a(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Chlorophyll Concentration, OC3 Algorithm
#     slope: 1.0
#     intercept: 0.0
#     units: mg m^-3
#     standard_name: chlorophyll_concentration_in_sea_water
#     bad_value_scaled: -32767.0
#     bad_value_unscaled: -32767.0
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Kd_490': <class 'netCDF4._netCDF4.Variable'>
# >i2 Kd_490(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Diffuse attenuation coefficient at 490 nm, KD2 algorithm
#     slope: 0.0002
#     intercept: 0.0
#     units: m^-1
#     standard_name: diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -6.5534
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'pic': <class 'netCDF4._netCDF4.Variable'>
# >i2 pic(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Calcite Concentration, Balch and Gordon
#     slope: 2e-06
#     intercept: 0.065
#     units: mol m^-3
#     standard_name: mole_concentration_of_particulate_inorganic_carbon_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.00053400546
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'poc': <class 'netCDF4._netCDF4.Variable'>
# >i2 poc(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Particulate Organic Carbon, D. Stramski, 2007 (443/555 version)
#     slope: 0.2
#     intercept: 6400.0
#     units: mg m^-3
#     standard_name: mole_concentration_of_particulate_organic_carbon_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -153.3999
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'cdom_index': <class 'netCDF4._netCDF4.Variable'>
# >i2 cdom_index(Number of Scan Lines, Pixels per Scan Line)
#     long_name: CDOM index, Morel 2009 algorithm
#     slope: 0.0002
#     intercept: 6.4
#     units: dimensionless
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.15339994
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'ipar': <class 'netCDF4._netCDF4.Variable'>
# >i2 ipar(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Instantaneous Photosynthetically Available Radiation
#     slope: 1e-07
#     intercept: 0.0
#     units: Ein m^-2 s^-1
#     standard_name: downwelling_photosynthetic_photon_radiance_in_sea_water
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.0032767002
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'nflh': <class 'netCDF4._netCDF4.Variable'>
# >i2 nflh(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Normalized Fluorescence Line Height
#     slope: 1e-05
#     intercept: 0.0
#     units: mW cm^-2 um^-1 sr^-1
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.32766998
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'par': <class 'netCDF4._netCDF4.Variable'>
# >i2 par(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Photosynthetically Available Radiation, R. Frouin
#     slope: 0.002
#     intercept: 65.5
#     units: Ein m^-2 day^-1
#     standard_name: surface_downwelling_photosynthetic_photon_flux_in_air
#     bad_value_scaled: -32767
#     bad_value_unscaled: -0.03400421
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -32767 used, 'l2_flags': <class 'netCDF4._netCDF4.Variable'>
# >i4 l2_flags(Number of Scan Lines, Pixels per Scan Line)
#     long_name: Level-2 Processing Flags
#     slope: 1.0
#     intercept: 0.0
#     units: dimensionless
#     f01_name: ATMFAIL
#     f02_name: LAND
#     f03_name: PRODWARN
#     f04_name: HIGLINT
#     f05_name: HILT
#     f06_name: HISATZEN
#     f07_name: COASTZ
#     f08_name: SPARE
#     f09_name: STRAYLIGHT
#     f10_name: CLDICE
#     f11_name: COCCOLITH
#     f12_name: TURBIDW
#     f13_name: HISOLZEN
#     f14_name: SPARE
#     f15_name: LOWLW
#     f16_name: CHLFAIL
#     f17_name: NAVWARN
#     f18_name: ABSAER
#     f19_name: SPARE
#     f20_name: MAXAERITER
#     f21_name: MODGLINT
#     f22_name: CHLWARN
#     f23_name: ATMWARN
#     f24_name: SPARE
#     f25_name: SEAICE
#     f26_name: NAVFAIL
#     f27_name: FILTER
#     f28_name: SSTWARN
#     f29_name: SSTFAIL
#     f30_name: HIPOL
#     f31_name: PRODFAIL
#     f32_name: SPARE
# unlimited dimensions:
# current shape = (1054, 403)
# filling on, default _FillValue of -2147483647 used, 'wavelength': <class 'netCDF4._netCDF4.Variable'>
# >i4 wavelength(total band number)
#     long_name: Wavelengths
#     units: nm
# unlimited dimensions:
# current shape = (24,)
# filling on, default _FillValue of -2147483647 used, 'cntl_pt_cols': <class 'netCDF4._netCDF4.Variable'>
# >i4 cntl_pt_cols(Number of Pixel Control Points)
#     long_name: Pixel control points
#     units: none
# unlimited dimensions:
# current shape = (403,)
# filling on, default _FillValue of -2147483647 used, 'cntl_pt_rows': <class 'netCDF4._netCDF4.Variable'>
# >i4 cntl_pt_rows(Number of Scan Lines)
#     long_name: Scan control points
#     units: none
# unlimited dimensions:
# current shape = (1054,)
# filling on, default _FillValue of -2147483647 used, 'vcal_gain': <class 'netCDF4._netCDF4.Variable'>
# >f4 vcal_gain(band number)
#     long_name: Vicarious Calibration Gain
#     units: dimensionless
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vcal_offset': <class 'netCDF4._netCDF4.Variable'>
# >f4 vcal_offset(band number)
#     long_name: Vicarious Calibration Offset
#     units: mW cm^-2 um^-1 sr^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'F0': <class 'netCDF4._netCDF4.Variable'>
# >f4 F0(band number)
#     long_name: Mean Solar Flux
#     units: mW cm^-2 um^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'k_oz': <class 'netCDF4._netCDF4.Variable'>
# >f4 k_oz(band number)
#     long_name: Ozone Absorption Coefficient
#     units: cm^-1
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Tau_r': <class 'netCDF4._netCDF4.Variable'>
# >f4 Tau_r(band number)
#     long_name: Rayleigh Optical Thickness
#     units: dimensionless
# unlimited dimensions:
# current shape = (16,)
# filling on, default _FillValue of 9.969209968386869e+36 used}
# <ipython-input-8-924b8f1df4c1>:2: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(fh.variables)

# %% [markdown]
# ### Notice that you have the following variables:
# ## * Time information
#     * Year
#     * Day of the Year
#     * Milliseconds of Day
# ## * Scan line information
#     * Tilt angle for scan line
#     * Scan start-pixel longitude
#     * Scan center-pixel longitude
#     * Scan end-pixel longitude
#     * Scan start-pixel latitude
#     * Scan center-pixel latitude
#     * Scan end-pixel latitude
#     * (...)
# ##

# %%
file = 'A2005243140500.L2_LAC_OC.x 2.hdf'
fh = Dataset(file, mode='r')
lon_mld = np.array(fh['longitude'])-360
lat_mld = np.array(fh['latitude'])
mld = np.array(fh['mlotst'])
mld[mld == 32767] = np.nan
mld = np.swapaxes(np.swapaxes(mld, 0, 2), 0, 1)
time = np.array(fh['time'])


pixel1 = pd.read_csv('pixel1_monthly.csv')
pixel2 = pd.read_csv('pixel2_monthly.csv')
pixel3 = pd.read_csv('pixel3_monthly.csv')

# %% [markdown]
# Let's print one of the datasets to check the structure

# %%
print(pixel1)

# %% [markdown]
# You will notice the data corresponds to monthly-averaged Chl-a concentrations.
#
# Let's extract the data from each dataset and calculate the mean, min, max, standard deviation

# %%
pixel1_chla = pixel1['Chl-a'].values
pixel2_chla = pixel2['Chl-a'].values
pixel3_chla = pixel3['Chl-a'].values

# Pixel 1
pixel1_mean = np.nanmean(pixel1_chla)
pixel1_min = np.nanmin(pixel1_chla)
pixel1_max = np.nanmax(pixel1_chla)
pixel1_stdev = np.nanstd(pixel1_chla)

# Pixel 2
pixel2_mean = np.nanmean(pixel2_chla)
pixel2_min = np.nanmin(pixel2_chla)
pixel2_max = np.nanmax(pixel2_chla)
pixel2_stdev = np.nanstd(pixel2_chla)

# Pixel 3
pixel3_mean = np.nanmean(pixel3_chla)
pixel3_min = np.nanmin(pixel3_chla)
pixel3_max = np.nanmax(pixel3_chla)
pixel3_stdev = np.nanstd(pixel3_chla)

print('The Chl-a dataset of pixel 1 has:',
      'mean = {:.2f} mg.m/3, minimum = {:.2f} mg.m/3, maximum = {:.2f} mg.m/3 and standard deviation = {:.2f} mg.m/3 \n'.format(pixel1_mean, pixel1_min, pixel1_max, pixel1_stdev))

print('The Chl-a dataset of pixel 2 has:',
      'mean = {:.2f} mg.m/3, minimum = {:.2f} mg.m/3, maximum = {:.2f} mg.m/3 and standard deviation = {:.2f} mg.m/3 \n'.format(pixel2_mean, pixel2_min, pixel2_max, pixel2_stdev))

print('The Chl-a dataset of pixel 3 has:',
      'mean = {:.2f} mg.m/3, minimum = {:.2f} mg.m/3, maximum = {:.2f} mg.m/3 and standard deviation = {:.2f} mg.m/3 \n'.format(pixel3_mean, pixel3_min, pixel3_max, pixel3_stdev))

# %% [markdown]
# ## Other simple to calculate and useful calculations using numpy are:
# ``` python
# np.ptp(array) # Calculates range (maximum - minimum)
# np.percentile(array) # Calculates the q-th percentile
# np.quantile(array) # Calculates the q-th quantile
# np.median(array) # Calculates the median
# ```
# ## Now say we want to plot each dataset

# %%
print('Pixel 1 Plot')
plt.plot(pixel1_chla)

# %%
print('Pixel 2 Plot')
plt.plot(pixel2_chla)

# %%
print('Pixel 3 Plot')
plt.plot(pixel3_chla)

# %% [markdown]
# They all seem different but let's compare put them in the same plot for comparison.

# %%
plt.plot(pixel1_chla)
plt.plot(pixel2_chla)
plt.plot(pixel3_chla)

# %% [markdown]
# We can use matplotlib options to improve our plot.

# %%
plt.figure(figsize=(12,6))
plt.plot(pixel1_chla, c='r', label='Pixel 1')
plt.plot(pixel2_chla, c='b', linestyle='--', label='Pixel 2')
plt.plot(pixel3_chla, c='k', linestyle=':', label='Pixel 3')
plt.xlabel('Years', fontsize=14)
plt.ylabel('Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.xticks(ticks=np.arange(0, len(pixel1_chla), 12), labels=np.arange(1998, 2021))
plt.xlim(0,len(pixel1_chla))
plt.ylim(0, 2)
plt.title('Pixel Chl-$\it{a}$ comparison', fontsize=18)
plt.legend(loc=0, fontsize=14)
#plt.tight_layout()

# %% [markdown]
# ## Other types of plots you can do to compare one dimensional datasets!
# * Scatter plots
# * Histograms
# * Boxplots
# * etc.

# %%
plt.figure()
plt.scatter(pixel1_chla, pixel2_chla, s=10)
plt.xlabel('Pixel 1 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.ylabel('Pixel 2 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.title('Scatter Plot - Pixel 1 vs. Pixel 2', fontsize=18)
plt.figure()
plt.scatter(pixel1_chla, pixel3_chla, s=10, c='grey')
plt.xlabel('Pixel 1 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.ylabel('Pixel 3 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.title('Scatter Plot - Pixel 1 vs. Pixel 3', fontsize=18)

# %%
plt.figure()
plt.hist(pixel1_chla, color='r')
plt.xlabel('Pixel 1 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.ylabel('N', fontsize=14)
plt.title('Histogram - Pixel 1', fontsize=18)
plt.xlim(0,2)
plt.ylim(0,150)
plt.figure()
plt.hist(pixel2_chla, color='b')
plt.xlabel('Pixel 2 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.ylabel('N', fontsize=14)
plt.title('Histogram - Pixel 2', fontsize=18)
plt.xlim(0,2)
plt.ylim(0,150)
plt.figure()
plt.hist(pixel3_chla, color='b')
plt.xlabel('Pixel 3 Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.ylabel('N', fontsize=14)
plt.title('Histogram - Pixel 3', fontsize=18)
plt.xlim(0,2)
plt.ylim(0,150)

# %%
pixel1_chla_nonans = pixel1_chla[~np.isnan(pixel1_chla)] # Remove missing values
plt.figure()
bplot = plt.boxplot([pixel1_chla_nonans, pixel2_chla, pixel3_chla], notch = True, patch_artist=True, vert=True)
# fill with colors
colors = ['r', 'b', 'k']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)
for patch, color in zip(bplot['medians'], colors):
    patch.set_color('w')
    patch.set_linewidth(2)
plt.xlabel('Pixels', fontsize=14)
plt.ylabel('Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.title('Boxplot Comparison', fontsize=18)

# %% [markdown]
# ## Last but not least, how to save an image.
#
# Let's use the boxplots image as an example

# %%
pixel1_chla_nonans = pixel1_chla[~np.isnan(pixel1_chla)] # Remove missing values
plt.figure()
bplot = plt.boxplot([pixel1_chla_nonans, pixel2_chla, pixel3_chla], notch = True, patch_artist=True, vert=True)
# fill with colors
colors = ['r', 'b', 'k']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)
for patch, color in zip(bplot['medians'], colors):
    patch.set_color('w')
    patch.set_linewidth(2)
plt.xlabel('Pixels', fontsize=14)
plt.ylabel('Chl-$\it{a}$ (mg.m$^{-3}$)', fontsize=14)
plt.title('Boxplot Comparison', fontsize=18)
#plt.show()
# Save in .png
plt.savefig('boxplots_TP4.png',format = 'png', bbox_inches = 'tight', dpi = 100)
# Save in .jpeg
plt.savefig('boxplots_TP4.jpeg',format = 'jpeg', bbox_inches = 'tight', dpi = 100)
# Save in .pdf
plt.savefig('boxplots_TP4.pdf',format = 'pdf', bbox_inches = 'tight', dpi = 100)
